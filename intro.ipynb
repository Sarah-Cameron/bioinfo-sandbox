# %% [markdown]
# # Welcome to the Bioinformatics Sandbox
#
# You are running a real Linux computer **in your browser** — nothing was installed on your laptop.
#
# ## Two ways to work here
#
# 1. **This notebook** — run Python by clicking a cell and pressing `Shift+Enter`.
# 2. **A bash terminal** — go to **File ▸ New ▸ Terminal** (or the Launcher tab) to get a command line.
#
# > Tip: anything you create here disappears when the session ends. Download files you want to keep (right-click ▸ Download).

# %% [markdown]
# ## Part 1 — Python in the notebook

# %%
print("Hello, bioinformatics!")
seq = "ATGCGTACGTTAGC"
gc = (seq.count("G") + seq.count("C")) / len(seq)
print(f"GC content: {gc:.1%}")

# %% [markdown]
# ## Part 2 — Run shell commands
#
# In a notebook, a line starting with `!` runs in the shell. (In a real Terminal tab, drop the `!`.)

# %%
# !pwd          # where am I?
# !ls -la       # what's here?
# !head -4 data/sample.fasta

# %%
# Run the sample script
# !python scripts/count_bases.py data/sample.fasta

# %%
# Command-line bioinformatics tools are installed too
# !seqkit stats data/sample.fasta

# %% [markdown]
# ## Part 3 — Your turn
#
# Open a **Terminal** (File ▸ New ▸ Terminal) and try:
#
# ```bash
# pwd
# ls
# cd data
# ls
# cat sample.fasta
# cd ..
# python scripts/count_bases.py data/sample.fasta
# ```
#
# Then make your own script with `nano myscript.py` and run it with `python myscript.py`.
#
# See `BASH_CHEATSHEET.md` for more commands.
